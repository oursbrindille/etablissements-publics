# %% [markdown]
# # Etude du jeu de données de la liste des établissements publics

# %% [markdown]
# Jeu de données : https://www.data.gouv.fr/fr/datasets/r/73302880-e4df-4d4c-8676-1a61bb997f3d

# %%
import xml.etree.ElementTree as ET
import os
import tqdm
import pandas as pd

# %%
path = 'all_20191212/organismes/'

files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.xml' in file:
            files.append(os.path.join(r, file))

# %%
df_cols = ["idOrg", "codeInsee", "pivotLocal", "nom", "adresse", "codePostal", "nomCommune", "latitude", "longitude"]
rows = []

for f in files:
    tree = ET.parse(f)
    root = tree.getroot()
    
    idOrg = root.attrib.get("id")
    codeInsee = root.attrib.get("codeInsee")
    pivotLocal = root.attrib.get("pivotLocal")

    for node in root:
        if node.tag == 'Nom':
            nom = node.text
        if node.tag == 'Adresse':
            for node2 in list(node):
                if node2.tag == 'Ligne':
                    adresse = node2.text
                if node2.tag == 'CodePostal':
                    codePostal = node2.text
                if node2.tag == 'NomCommune':
                    nomCommune = node2.text
                if node2.tag == 'Localisation':
                    for node3 in list(node2):
                        if node3.tag == 'Latitude':
                            latitude = node3.text
                        if node3.tag == 'Longitude':
                            longitude = node3.text
    
    rows.append({"idOrg": idOrg, "codeInsee": codeInsee, "pivotLocal": pivotLocal, "nom": nom, "adresse": adresse, 
                 "codePostal": codePostal, "nomCommune": nomCommune, "latitude": latitude, "longitude": longitude})

# %%
out_df = pd.DataFrame(rows, columns = df_cols)

# %%
out_df
# Out:
#                                          idOrg codeInsee  \
# 0      accompagnement_personnes_agees-01322-01     01322
# 1                                adil-01053-01     01053
# 2                                afpa-01053-01     01053
# 3                                anah-01053-01     01053
# 4                    banque_de_france-01053-01     01053
# ...                                        ...       ...
# 61810                              te-98818-01     98818
# 61811                             tgi-98811-01     98811
# 61812                             tgi-98814-01     98814
# 61813                             tgi-98818-01     98818
# 61814               tribunal_commerce-98818-01     98818
#
#                            pivotLocal  \
# 0      accompagnement_personnes_agees
# 1                                adil
# 2                                afpa
# 3                                anah
# 4                    banque_de_france
# ...                               ...
# 61810                              te
# 61811                             tgi
# 61812                             tgi
# 61813                             tgi
# 61814               tribunal_commerce
#
#                                                      nom  \
# 0      Plateforme d'accompagnement et de répit pour l...
# 1      Agence départementale d'information sur le log...
# 2      Agence nationale pour la formation professionn...
# 3             Agence nationale de l'habitat (Anah) - Ain
# 4      Banque de France - Succursale départementale -...
# ...                                                  ...
# 61810                    Tribunal pour enfants de Nouméa
# 61811  Section Détachée du Tribunal de Première Insta...
# 61812  Section Détachée du Tribunal de Première Insta...
# 61813            Tribunal de Première Instance de Nouméa
# 61814               Tribunal mixte de commerce de Nouméa
#
#                              adresse codePostal       nomCommune  \
# 0                     Rue du Collège      01600         Reyrieux
# 1      34 rue du Général-Delestraint      01000  Bourg-en-Bresse
# 2                17 route de Seillon      01000  Bourg-en-Bresse
# 3                             CS 415      01000  Bourg-en-Bresse
# 4                           CS 30001      01000  Bourg-en-Bresse
# ...                              ...        ...              ...
# 61810                          BP F4      98848     NOUMEA CEDEX
# 61811           30 rue Lucien ALLARD      98859             KONE
# 61812                          LIFOU      98820               WE
# 61813                          BP F4      98848     NOUMEA CEDEX
# 61814                          BP F4      98848     NOUMEA CEDEX
#
#              latitude      longitude
# 0           45.930657       4.814821
# 1           46.196535      5.2191997
# 2          46.1854081      5.2330388
# 3          46.2024681      5.2174282
# 4           46.200193       5.216618
# ...               ...            ...
# 61810     -22.2747558    166.4490616
# 61811      -21.060339     164.865749
# 61812     -21.0384968    167.2405153
# 61813  -22.2771239522  166.447959765
# 61814     -22.2747558    166.4490616
#
# [61815 rows x 9 columns]

# %%
out_df.count()
# Out:
# idOrg         61815
# codeInsee     61815
# pivotLocal    61815
# nom           61815
# adresse       61815
# codePostal    61815
# nomCommune    61815
# latitude      61810
# longitude     61809
# dtype: int64

# %%
out_df.to_csv("liste_etablissements_publics.csv")

# %%
explore_df = out_df[out_df['nom'].str.contains('Matignon')]
explore_df
# Out:
#                       idOrg codeInsee   pivotLocal  \
# 12294  gendarmerie-22143-01     22143  gendarmerie
# 12460       mairie-22143-01     22143       mairie
# 12713         msap-22143-01     22143         msap
#
#                                                   nom  \
# 12294               Brigade de gendarmerie - Matignon
# 12460                               Mairie - Matignon
# 12713  Maison de services au public (MSAP) - Matignon
#
#                                   adresse codePostal nomCommune     latitude  \
# 12294                13 Rue du Pont-Brûlé      22550   Matignon  48.59881457
# 12460                         7 rue Lédan      22550   Matignon   48.5869523
# 12713  1 place Rioust-des-Villes-Audrains      22550   Matignon    48.596892
#
#         longitude
# 12294  -2.2890319
# 12460  -2.2905033
# 12713   -2.291807

# %%
out_df.pivotLocal.unique()
# Out:
# array(['accompagnement_personnes_agees', 'adil', 'afpa', 'anah',
#        'banque_de_france', 'bav', 'bureau_de_douane', 'caf', 'cap_emploi',
#        'cci', 'cdad', 'cdg', 'centre_impots_fonciers',
#        'centre_penitentiaire', 'cg', 'chambre_agriculture',
#        'chambre_metier', 'chambre_notaires', 'cicas', 'cidf', 'cij',
#        'cio', 'cirfa', 'civi', 'clic', 'cnfpt', 'commissariat_police',
#        'commission_conciliation', 'conciliateur_fiscal', 'cpam', 'crib',
#        'ddcs', 'ddpp', 'ddt', 'direccte_ut', 'dreal_ut', 'epci', 'fdapp',
#        'fdc', 'gendarmerie', 'gendarmerie_moto', 'greta',
#        'huissiers_justice', 'hypotheque', 'inspection_academique', 'maia',
#        'mairie', 'maison_handicapees', 'mission_locale', 'mjd', 'msa',
#        'msap', 'onac', 'ordre_avocats', 'pcb', 'permanence_juridique',
#        'pif', 'pmi', 'pole_emploi', 'prefecture',
#        'prefecture_greffe_associations', 'prudhommes', 'sie', 'sip',
#        'sous_pref', 'spip', 'te', 'tgi', 'ti', 'tresorerie',
#        'tribunal_commerce', 'urssaf', 'epide', 'ddcspp', 'maison_arret',
#        '', 'apec', 'bsn', 'credit_municipal', 'crous', 'dml', 'drddi',
#        'ofii', 'paierie_departementale', 'prs', 'rectorat', 'sde', 'suio',
#        'ta', 'ccd', 'centre_detention', 'maison_centrale', 'ademe',
#        'agefiph', 'caa', 'carsat', 'cirgn', 'cour_appel', 'cr', 'drac',
#        'draf', 'dreal', 'esm', 'paierie_regionale', 'apecita', 'cadastre',
#        'ars_antenne', 'prefecture_region', 'csl', 'Maison-metropole-Lyon',
#        'driea_ut', 'paris_mairie', 'paris_ppp', 'paris_ppp_antenne',
#        'paris_ppp_antenne_cni_passeport',
#        'paris_ppp_certificat_immatriculation', 'paris_ppp_gesvres',
#        'paris_ppp_naturalisation', 'paris_ppp_permis_conduire',
#        'mairie_com'], dtype=object)

# %%
df = out_df[out_df['pivotLocal'] == 'greta']

# %%
df.count()
# Out:
# idOrg         186
# codeInsee     186
# pivotLocal    186
# nom           186
# adresse       186
# codePostal    186
# nomCommune    186
# latitude      186
# longitude     186
# dtype: int64

# %%
import folium

# %%
m = folium.Map(location=[46.759281,2.401860], tiles="OpenStreetMap", zoom_start=6)

# %%
data = df.dropna(subset=['longitude', 'latitude', 'nom'])

# %%
for index, row in data.iterrows():
    folium.Marker([row['latitude'],row['longitude']], popup='<i>'+row['nom']+'</i>', tooltip=row['nom'], icon=folium.Icon()).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
